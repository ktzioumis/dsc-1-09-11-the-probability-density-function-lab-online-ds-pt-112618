# %% [markdown]
# # The Probability Density Function (PDF) - Lab
#
# ## Introduction
#
# In this lab we will look at building visualizations known as **density plots** to estimate the probability density for a given set of data.
#
# ## Objectives
#
# You will be able to:
#
# * Calculate the PDF from given dataset containing real valued random variables
# * Plot density functions and comment on the shape of the plot
# * Plot density functions using seaborn
#
#
# ## Let's get started!
#
# We'll import all the required libraries for you for this lab.

# %%
# Import required libraries
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import pandas as pd

# %% [markdown]
# #### Import the dataset 'weight-height.csv' as pandas dataframe . Calculate the mean and standard deviation for weights and heights for male and female individually.
#
# Hint : Use your pandas dataframe subsetting skills like loc(), iloc() and groupby()

# %%
data = pd.read_csv('weight-height.csv')
data.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
data.Gender.value_counts()
# Out:
# Male      5000
# Female    5000
# Name: Gender, dtype: int64

# %%
male_df =  data.loc[data['Gender']=='Male']

female_df =  data.loc[data['Gender']=='Female']

# %%
print(male_df.describe(),'\n', female_df.describe())


  

# Male Height mean: 69.02634590621737
# Male Height sd: 2.8633622286606517
# Male Weight mean: 187.0206206581929
# Male Weight sd: 19.781154516763813
# Female Height mean: 63.708773603424916
# Female Height sd: 2.696284015765056
# Female Weight mean: 135.8600930074687
# Female Weight sd: 19.022467805319007
# Out:
#             Height       Weight
# count  5000.000000  5000.000000
# mean     69.026346   187.020621
# std       2.863362    19.781155
# min      58.406905   112.902939
# 25%      67.174679   173.887767
# 50%      69.027709   187.033546
# 75%      70.988744   200.357802
# max      78.998742   269.989699
#              Height       Weight
# count  5000.000000  5000.000000
# mean     63.708774   135.860093
# std       2.696284    19.022468
# min      54.263133    64.700127
# 25%      61.894441   122.934096
# 50%      63.730924   136.117583
# 75%      65.563565   148.810926
# max      73.389586   202.237214

# %%
male_df.Height.mean()
# Out:
# 69.02634590621741

# %% [markdown]
# #### Plot overlapping normalized histograms for male and female heights - use binsize = 10, set alpha level so that overlap can be visualized

# %%
#theirs

# %%
# Record your observations - are these inline with your personal observations?
plt.hist(male_df.Height, bins =10,color='red', label ='Male', alpha =.5,normed=True)
plt.hist(female_df.Height, bins=10, color='blue', label='Female',alpha=.5, normed=True)
plt.legend()
plt.show()
# Out:
# D:\Kosta\Ana3\envs\learn-env\lib\site-packages\matplotlib\axes\_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %% [markdown]
# #### Write a function density() that takes in a random variable and calculates the density function using `np.hist` and interpolation. The function should return two lists carrying x and y coordinates for plotting the density functio

# %%
def density(x):
    hiss=np.histogram(x, normed=True)
    x2=hiss[0]
    y=[]
    for i in range(len(x2)):
        y.append((hiss[1][i]+hiss[1][i+1])/2)
    return y, x2
    



# Generate test data and test the function - uncomment to run the test
np.random.seed(5)
mu, sigma = 0, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 100)
x,y = density(s)
plt.plot(x,y, label = 'test')
plt.legend()
# Out:
# D:\Kosta\Ana3\envs\learn-env\lib\site-packages\ipykernel_launcher.py:2: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.

# %%
x,y=density(s)
x,y
# Out:
# D:\Kosta\Ana3\envs\learn-env\lib\site-packages\ipykernel_launcher.py:2: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.
# ([-0.25951650089410394,
#   -0.20661190935780055,
#   -0.1537073178214972,
#   -0.10080272628519386,
#   -0.0478981347488905,
#   0.00500645678741285,
#   0.05791104832371621,
#   0.11081563986001958,
#   0.1637202313963229,
#   0.2166248229326263],
#  array([0.18901951, 0.18901951, 0.75607804, 1.51215608, 5.10352679,
#         4.15842923, 3.02431217, 2.26823413, 1.13411706, 0.56705853]))

# %% [markdown]
# #### Add Overlapping density plots for male and female heights to the histograms plotted earlier

# %%
# You code here 
male_line=density(male_df.Height)
female_line=density(female_df.Height)
# Out:
# D:\Kosta\Ana3\envs\learn-env\lib\site-packages\ipykernel_launcher.py:2: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.

# %%
plt.hist(male_df.Height, bins =10,color='red', label ='Male', alpha =.5,normed=True)
plt.hist(female_df.Height, bins=10, color='blue', label='Female',alpha=.5, normed=True)
plt.plot(male_line[0],male_line[1])
plt.plot(female_line[0],female_line[1])
plt.legend()
plt.show()
# Out:
# D:\Kosta\Ana3\envs\learn-env\lib\site-packages\matplotlib\axes\_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
#theirs

# %% [markdown]
# #### Repeat above exerice for male and female weights

# %%
plt.hist(male_df.Weight, bins =10,color='red', label ='Male', alpha =.5,normed=True)
plt.hist(female_df.Weight, bins=10, color='blue', label='Female',alpha=.5, normed=True)
plt.plot(density(male_df.Weight)[0],density(male_df.Weight)[1])
plt.plot(density(female_df.Weight)[0],density(female_df.Weight)[1])
plt.legend()
plt.show()
# Out:
# D:\Kosta\Ana3\envs\learn-env\lib\site-packages\matplotlib\axes\_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
# D:\Kosta\Ana3\envs\learn-env\lib\site-packages\ipykernel_launcher.py:2: VisibleDeprecationWarning: Passing `normed=True` on non-uniform bins has always been broken, and computes neither the probability density function nor the probability mass function. The result is only correct if the bins are uniform, when density=True will produce the same result anyway. The argument will be removed in a future version of numpy.

# %%
#theirs

# %% [markdown]
# #### Write your observations in the cell below.

# %%
# Record your observations - are these inline with your personal observations?


# So whats the takeaway when comparing male and female heights and weights

# %% [markdown]
# #### Repeat Above experiments in seaborn and compare with your results.

# %%
# import seaborn as sns
sns.distplot(male_df.Height,label='Male')
sns.distplot(female_df.Height, label='Female')
plt.title('comparing heights')
plt.legend()
# Out:
# D:\Kosta\Ana3\envs\learn-env\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# Out:
# Text(0.5,1,'Comparing weights')

# %%
# Out:
# Text(0.5,1,'Comparing Weights')

# %%
# Your comments on the two approaches here. 
# are they similar ? what makes them different if they are ?

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lesson we saw how to build the probability density curves visually for given datasets and compare on the distribution visually by looking at the spread , center and overlap between data elements. This is a useful EDA technique and can be used to answer some initial questions before embarking on a complex analytics journey.
